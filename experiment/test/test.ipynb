# %% [markdown]
# # Init Testing Environment

# %%
import requests
import logging
import argparse
import os
from rxoms.utils import rxoms_utils as rutils

DEFAULT_DATA_PATH = "/data/anomaly_data/"
DEFAULT_CONFIG_FOLDER = "/configuration/service/"
DEFAULT_PATH_LEVEL = 2

# User must export RXOMS_PATH before using
RXOMS_PATH = rutils.get_parent_directory(os.getcwd(), DEFAULT_PATH_LEVEL)
logging.basicConfig(
    format="%(asctime)s:%(levelname)s -- %(message)s", level=logging.INFO
)
logging.info(f"RXOMS_PATH: {RXOMS_PATH}")

# Bug: 
# Python 3.12: https://stackoverflow.com/questions/77364550/attributeerror-module-pkgutil-has-no-attribute-impimporter-did-you-mean
# python -m ensurepip --upgrade
# python -m pip install --upgrade setuptools
# Out:
# 2024-10-21 22:02:03,234:INFO -- RXOMS_PATH: /Users/tringuyen/workplace/Study/PhD/Github/rdsea/RXOMS

# %% [markdown]
# # Test APIs of the Knowledge Graph

# %%
# Test Knowledge Graph APIs
from rxoms.utils import rxoms_utils as rutils


def test_kg_api(url, method, payload=None, log=False):
    try:
        if method == "GET":
            response = requests.get(url)
        elif method == "POST":
            response = requests.post(url, json=payload)
        else:
            logging.error("Method not supported")
            return
        logging.info(f"Status Code: {response.status_code}")
        if log:
            logging.info(f"Response: {response.json()}")
    except Exception as e:
        logging.error(f"Error: {e}")


config = rutils.load_config(f"{RXOMS_PATH}{DEFAULT_CONFIG_FOLDER}test_kg_api.yaml")
"""
    Call tet_kg() with api=-1 to test all APIs, or specify the api number to test a specific API
    /graph api:0
    /get_cti_by_id api:1
    /get_dt_by_mac  00:00:00:00:00:07 api:2
    /get_flow api:3
    /get_incident_metadata api:4
    /update_cti_by_id api:5
    /update_asset_by_mac api:6
    /update_switch api:7
    /reset_graph api:8
    /update_flow api:9
    /trace_root_cause_by_flow api:10
    trace_root_cause_by_switch api:11
    /trace_consequence_by_switch api:12
    /get_detector api:13
"""
url_kg_list = config["url_kg_list"]
payload_kg_list = config["payload_kg_list"]
method_kg_list = config["method_kg_list"]


def test_kg(api=-1, log=False):
    if api is -1:
        for i in range(len(url_kg_list)):
            logging.info(f"Testing API: {i}")
            test_kg_api(
                url=url_kg_list[i],
                method=method_kg_list[i],
                payload=payload_kg_list[i],
                log=log,
            )
    else:
        test_kg_api(
            url=url_kg_list[api],
            method=method_kg_list[api],
            payload=payload_kg_list[api],
            log=log,
        )


test_kg(-1, log=False)
# Out:
# <>:45: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:45: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /var/folders/mm/jzwsx21s39g32xm2n2bk_1440000gn/T/ipykernel_6501/4179679322.py:45: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   if api is -1:
# 2024-10-22 12:18:33,601:INFO -- Testing API: 0
# 2024-10-22 12:18:33,663:INFO -- Status Code: 200
# 2024-10-22 12:18:33,664:INFO -- Testing API: 1
# 2024-10-22 12:18:33,688:INFO -- Status Code: 200
# 2024-10-22 12:18:33,689:INFO -- Testing API: 2
# 2024-10-22 12:18:33,713:INFO -- Status Code: 200
# 2024-10-22 12:18:33,714:INFO -- Testing API: 3
# 2024-10-22 12:18:33,737:INFO -- Status Code: 200
# 2024-10-22 12:18:33,738:INFO -- Testing API: 4
# 2024-10-22 12:18:33,759:INFO -- Status Code: 200
# 2024-10-22 12:18:33,761:INFO -- Testing API: 5
# 2024-10-22 12:18:33,784:INFO -- Status Code: 200
# 2024-10-22 12:18:33,784:INFO -- Testing API: 6
# 2024-10-22 12:18:33,809:INFO -- Status Code: 200
# 2024-10-22 12:18:33,810:INFO -- Testing API: 7
# 2024-10-22 12:18:33,836:INFO -- Status Code: 200
# 2024-10-22 12:18:33,837:INFO -- Testing API: 8
# 2024-10-22 12:18:33,921:INFO -- Status Code: 200
# 2024-10-22 12:18:33,922:INFO -- Testing API: 9
# 2024-10-22 12:18:33,947:INFO -- Status Code: 200
# 2024-10-22 12:18:33,948:INFO -- Testing API: 10
# 2024-10-22 12:18:34,039:INFO -- Status Code: 200
# 2024-10-22 12:18:34,040:INFO -- Testing API: 11
# 2024-10-22 12:18:34,095:INFO -- Status Code: 200
# 2024-10-22 12:18:34,096:INFO -- Testing API: 12
# 2024-10-22 12:18:34,129:INFO -- Status Code: 200
# 2024-10-22 12:18:34,130:INFO -- Testing API: 13
# 2024-10-22 12:18:34,156:INFO -- Status Code: 200

# %% [markdown]
# # Test the whole RXOMS services with anomaly data

# %%
# Test Data Enrichment APIs
import pandas as pd
import time

data_path = str(RXOMS_PATH) + DEFAULT_DATA_PATH + "all_flow.csv"

url = "http://0.0.0.0:5051/anomaly_report"

# Read the data using pandas
df = pd.read_csv(data_path)

# Sort the data by the 'runtime' column
df_sorted = df.sort_values(by="runtime")

# Iterate over each row, convert it to a dictionary, and send it as a payload
for _, row in df_sorted.iterrows():
    pay_load = row.to_dict()
    logging.info(f"Sending payload: {pay_load}")
    response = requests.post(url, json=pay_load)
    logging.info(f"Response status code: {response.status_code}")
    logging.info(f"Response content: {response.content}")
    time.sleep(0.1)
# Out:
# 2024-10-22 12:39:43,079:INFO -- Sending payload: {'switch': 1, 'in_port': 1, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 368, 'byte_count': 553650, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 328, 'byte_count_shifted': 493170, 'packet_count_average': 6958.2, 'byte_count_average': 10548648.4, 'byte_count_average_norm': 0.9793685741094618, 'packet_count_average_norm': 0.975857500368026, 'byte_scores': 0.5, 'packet_scores': 0.499999445188199, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:43,178:INFO -- Response status code: 200
# 2024-10-22 12:39:43,178:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:43,281:INFO -- Sending payload: {'switch': 2, 'in_port': 4, 'eth_dst': '00:00:00:00:00:05', 'packet_count': 9083, 'byte_count': 13729086, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 6354, 'byte_count_shifted': 9604308, 'packet_count_average': 8571.5, 'byte_count_average': 12956139.0, 'byte_count_average_norm': 0.4179352402815858, 'packet_count_average_norm': 0.4179584717116869, 'byte_scores': 0.3751648941373466, 'packet_scores': 0.3751649237386498, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:43,383:INFO -- Response status code: 200
# 2024-10-22 12:39:43,383:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:43,488:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:06', 'packet_count': 10, 'byte_count': 8666, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 10, 'byte_count_shifted': 8666, 'packet_count_average': 10.9, 'byte_count_average': 4972.800000000001, 'byte_count_average_norm': 0.0430888952937786, 'packet_count_average_norm': 0.3122171945701356, 'byte_scores': 0.4999938665878154, 'packet_scores': 0.5000153507651093, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:43,589:INFO -- Response status code: 200
# 2024-10-22 12:39:43,589:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:43,690:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 4, 'byte_count': 168, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 3, 'byte_count_shifted': 126, 'packet_count_average': 6.800000000000001, 'byte_count_average': 6274.399999999998, 'byte_count_average_norm': 0.1206749797846532, 'packet_count_average_norm': 0.1458333333333333, 'byte_scores': 0.4999977846593486, 'packet_scores': 0.500018082487848, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:43,810:INFO -- Response status code: 200
# 2024-10-22 12:39:43,811:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:43,915:INFO -- Sending payload: {'switch': 1, 'in_port': 2, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 327, 'byte_count': 492580, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 249, 'byte_count_shifted': 375566, 'packet_count_average': 366.2000000000001, 'byte_count_average': 508728.00000000006, 'byte_count_average_norm': 0.1031792292048126, 'packet_count_average_norm': 0.1329076032727998, 'byte_scores': 0.5, 'packet_scores': 0.4999996440858183, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:44,015:INFO -- Response status code: 200
# 2024-10-22 12:39:44,015:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:44,116:INFO -- Sending payload: {'switch': 2, 'in_port': 4, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 16870, 'byte_count': 25488478, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 9599, 'byte_count_shifted': 14505590, 'packet_count_average': 511.6, 'byte_count_average': 916561.5, 'byte_count_average_norm': 0.0758108337616252, 'packet_count_average_norm': 0.0052238805970149, 'byte_scores': 0.4999977769512203, 'packet_scores': 0.5000000654364226, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:44,214:INFO -- Response status code: 200
# 2024-10-22 12:39:44,215:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:44,318:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:44,461:INFO -- Response status code: 200
# 2024-10-22 12:39:44,463:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:44,568:INFO -- Sending payload: {'switch': 2, 'in_port': 3, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 28915, 'byte_count': 43690924, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 9638, 'byte_count_shifted': 14556260, 'packet_count_average': 837.6, 'byte_count_average': 826259.4000000003, 'byte_count_average_norm': 0.0539806268616514, 'packet_count_average_norm': 0.221049007230575, 'byte_scores': 0.5000048842337138, 'packet_scores': 0.4999826260221902, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:44,670:INFO -- Response status code: 200
# 2024-10-22 12:39:44,671:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:44,776:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:03', 'packet_count': 2, 'byte_count': 84, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 2, 'byte_count_shifted': 84, 'packet_count_average': 119.1, 'byte_count_average': 121137.6, 'byte_count_average_norm': 0.9660186155134284, 'packet_count_average_norm': 0.9305555555555556, 'byte_scores': 0.4999990811933776, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:44,874:INFO -- Response status code: 200
# 2024-10-22 12:39:44,875:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:44,978:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 5.900000000000002, 'byte_count_average': 6936.6, 'byte_count_average_norm': 0.1546901051851547, 'packet_count_average_norm': 0.0904761904761905, 'byte_scores': 0.5000076671819695, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:45,077:INFO -- Response status code: 200
# 2024-10-22 12:39:45,077:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:45,180:INFO -- Sending payload: {'switch': 2, 'in_port': 1, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:45,276:INFO -- Response status code: 200
# 2024-10-22 12:39:45,276:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:45,382:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:45,478:INFO -- Response status code: 200
# 2024-10-22 12:39:45,479:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:45,584:INFO -- Sending payload: {'switch': 2, 'in_port': 5, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 98, 'byte_count': 148176, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 592.5, 'byte_count_average': 602522.1000000001, 'byte_count_average_norm': 0.0778623683070912, 'packet_count_average_norm': 0.2932681626305265, 'byte_scores': 0.499998537003274, 'packet_scores': 0.5000005099658618, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:45,683:INFO -- Response status code: 200
# 2024-10-22 12:39:45,683:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:45,789:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 4, 'byte_count': 168, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 3, 'byte_count_shifted': 126, 'packet_count_average': 5.199999999999999, 'byte_count_average': 5503.800000000003, 'byte_count_average_norm': 0.0823561228905237, 'packet_count_average_norm': 0.0638297872340425, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:45,886:INFO -- Response status code: 200
# 2024-10-22 12:39:45,887:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:45,991:INFO -- Sending payload: {'switch': 1, 'in_port': 5, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 3919, 'byte_count': 5920196, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 3514, 'byte_count_shifted': 5308758, 'packet_count_average': 740.2, 'byte_count_average': 993267.2, 'byte_count_average_norm': 0.1768079355442841, 'packet_count_average_norm': 0.2212825179316989, 'byte_scores': 0.4999746328602668, 'packet_scores': 0.5000001411074966, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:46,088:INFO -- Response status code: 200
# 2024-10-22 12:39:46,089:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:46,194:INFO -- Sending payload: {'switch': 1, 'in_port': 3, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 688, 'byte_count': 1039334, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 514, 'byte_count_shifted': 776246, 'packet_count_average': 786.3999999999999, 'byte_count_average': 905863.0, 'byte_count_average_norm': 0.0668023519791457, 'packet_count_average_norm': 0.1581849231519882, 'byte_scores': 0.4999972455719406, 'packet_scores': 0.5000002319159084, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:46,292:INFO -- Response status code: 200
# 2024-10-22 12:39:46,292:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:46,397:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:46,494:INFO -- Response status code: 200
# 2024-10-22 12:39:46,495:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:46,600:INFO -- Sending payload: {'switch': 2, 'in_port': 3, 'eth_dst': '00:00:00:00:00:05', 'packet_count': 6427, 'byte_count': 9712292, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 6313, 'byte_count_shifted': 9540846, 'packet_count_average': 3959.2, 'byte_count_average': 5982687.6, 'byte_count_average_norm': 0.2836169944930799, 'packet_count_average_norm': 0.2836609104266989, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:46,699:INFO -- Response status code: 200
# 2024-10-22 12:39:46,700:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:46,805:INFO -- Sending payload: {'switch': 2, 'in_port': 1, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:46,902:INFO -- Response status code: 200
# 2024-10-22 12:39:46,903:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:47,008:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:01', 'packet_count': 10, 'byte_count': 8666, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 10, 'byte_count_shifted': 8666, 'packet_count_average': 8.399999999999999, 'byte_count_average': 5829.799999999998, 'byte_count_average_norm': 0.0892132505175982, 'packet_count_average_norm': 0.2085308056872037, 'byte_scores': 0.5000084869814966, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:47,106:INFO -- Response status code: 200
# 2024-10-22 12:39:47,107:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:47,211:INFO -- Sending payload: {'switch': 2, 'in_port': 5, 'eth_dst': '00:00:00:00:00:05', 'packet_count': 538, 'byte_count': 812534, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 373, 'byte_count_shifted': 563976, 'packet_count_average': 331.6, 'byte_count_average': 500549.4, 'byte_count_average_norm': 0.0199696109467951, 'packet_count_average_norm': 0.0200005891189725, 'byte_scores': 0.5000903114071413, 'packet_scores': 0.5000903233175942, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:47,319:INFO -- Response status code: 200
# 2024-10-22 12:39:47,320:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:47,424:INFO -- Sending payload: {'switch': 2, 'in_port': 1, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 10, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:47,525:INFO -- Response status code: 200
# 2024-10-22 12:39:47,526:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:47,627:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 5.900000000000002, 'byte_count_average': 7201.6, 'byte_count_average_norm': 0.1683271237726683, 'packet_count_average_norm': 0.0904761904761905, 'byte_scores': 0.5000076671819695, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:47,730:INFO -- Response status code: 200
# 2024-10-22 12:39:47,731:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:47,832:INFO -- Sending payload: {'switch': 2, 'in_port': 1, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:47,931:INFO -- Response status code: 200
# 2024-10-22 12:39:47,931:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:48,036:INFO -- Sending payload: {'switch': 2, 'in_port': 3, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 29026, 'byte_count': 43858756, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 2025, 'byte_count_shifted': 3061800, 'packet_count_average': 783.4, 'byte_count_average': 804335.4000000003, 'byte_count_average_norm': 0.0456538280372478, 'packet_count_average_norm': 0.1899460576150579, 'byte_scores': 0.5000048842337138, 'packet_scores': 0.8333004314447434, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:48,132:INFO -- Response status code: 200
# 2024-10-22 12:39:48,133:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:48,238:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 4, 'byte_count': 168, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 3, 'byte_count_shifted': 126, 'packet_count_average': 5.299999999999997, 'byte_count_average': 5444.800000000003, 'byte_count_average_norm': 0.0791648636953701, 'packet_count_average_norm': 0.0691489361702126, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:48,334:INFO -- Response status code: 200
# 2024-10-22 12:39:48,334:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:48,439:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:03', 'packet_count': 3, 'byte_count': 1596, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 3, 'byte_count_shifted': 1596, 'packet_count_average': 118.9, 'byte_count_average': 121579.6, 'byte_count_average_norm': 0.9701674945651562, 'packet_count_average_norm': 0.9287037037037038, 'byte_scores': 0.833332303895767, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:48,534:INFO -- Response status code: 200
# 2024-10-22 12:39:48,534:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:48,638:INFO -- Sending payload: {'switch': 2, 'in_port': 4, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 17022, 'byte_count': 25718302, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 2413, 'byte_count_shifted': 3646986, 'packet_count_average': 504.6, 'byte_count_average': 904158.9, 'byte_count_average_norm': 0.0696893333351102, 'packet_count_average_norm': 0.0, 'byte_scores': 0.8333308634043579, 'packet_scores': 0.833328768055718, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:48,738:INFO -- Response status code: 200
# 2024-10-22 12:39:48,739:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:48,840:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:48,938:INFO -- Response status code: 200
# 2024-10-22 12:39:48,938:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:49,039:INFO -- Sending payload: {'switch': 2, 'in_port': 5, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 98, 'byte_count': 148176, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 580.5999999999999, 'byte_count_average': 629729.7, 'byte_count_average_norm': 0.0978493877195708, 'packet_count_average_norm': 0.280048878027105, 'byte_scores': 0.8333230489855264, 'packet_scores': 0.5000005099658618, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:49,138:INFO -- Response status code: 200
# 2024-10-22 12:39:49,138:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:49,242:INFO -- Sending payload: {'switch': 1, 'in_port': 5, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 4057, 'byte_count': 6128852, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 1847, 'byte_count_shifted': 2789724, 'packet_count_average': 730.5, 'byte_count_average': 902400.2, 'byte_count_average_norm': 0.1446189734743851, 'packet_count_average_norm': 0.2160903543517824, 'byte_scores': 0.8333089194636016, 'packet_scores': 0.8333287278304873, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:49,339:INFO -- Response status code: 200
# 2024-10-22 12:39:49,340:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:49,444:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:49,541:INFO -- Response status code: 200
# 2024-10-22 12:39:49,543:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:49,646:INFO -- Sending payload: {'switch': 2, 'in_port': 1, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:49,741:INFO -- Response status code: 200
# 2024-10-22 12:39:49,741:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:49,843:INFO -- Sending payload: {'switch': 1, 'in_port': 1, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 510, 'byte_count': 768354, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 470, 'byte_count_shifted': 707874, 'packet_count_average': 6938.5, 'byte_count_average': 10527169.6, 'byte_count_average_norm': 0.9770438679885388, 'packet_count_average_norm': 0.9726352290756825, 'byte_scores': 0.5, 'packet_scores': 0.8333325181527312, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:49,942:INFO -- Response status code: 200
# 2024-10-22 12:39:49,942:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:50,044:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:50,142:INFO -- Response status code: 200
# 2024-10-22 12:39:50,142:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:50,248:INFO -- Sending payload: {'switch': 2, 'in_port': 5, 'eth_dst': '00:00:00:00:00:05', 'packet_count': 700, 'byte_count': 1057478, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 535, 'byte_count_shifted': 808920, 'packet_count_average': 368.6, 'byte_count_average': 556585.6, 'byte_count_average_norm': 0.022700066870496, 'packet_count_average_norm': 0.0227252643671389, 'byte_scores': 0.5000903114071413, 'packet_scores': 0.5000903233175942, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:50,351:INFO -- Response status code: 200
# 2024-10-22 12:39:50,352:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:50,455:INFO -- Sending payload: {'switch': 1, 'in_port': 3, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 927, 'byte_count': 1400702, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 517, 'byte_count_shifted': 781704, 'packet_count_average': 779.3, 'byte_count_average': 925216.6000000002, 'byte_count_average_norm': 0.0730477918006013, 'packet_count_average_norm': 0.154720663576482, 'byte_scores': 0.833330945512033, 'packet_scores': 0.5000002319159084, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:50,552:INFO -- Response status code: 200
# 2024-10-22 12:39:50,553:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:50,657:INFO -- Sending payload: {'switch': 2, 'in_port': 1, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:50,757:INFO -- Response status code: 200
# 2024-10-22 12:39:50,757:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:50,861:INFO -- Sending payload: {'switch': 2, 'in_port': 3, 'eth_dst': '00:00:00:00:00:05', 'packet_count': 6427, 'byte_count': 9712292, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 6313, 'byte_count_shifted': 9540846, 'packet_count_average': 4579.1, 'byte_count_average': 6919627.6, 'byte_count_average_norm': 0.3287131068158316, 'packet_count_average_norm': 0.3287530733084074, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:50,956:INFO -- Response status code: 200
# 2024-10-22 12:39:50,956:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:51,060:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:01', 'packet_count': 11, 'byte_count': 10178, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 8, 'byte_count_shifted': 6564, 'packet_count_average': 8.399999999999999, 'byte_count_average': 5973.599999999998, 'byte_count_average_norm': 0.0966563146997928, 'packet_count_average_norm': 0.2085308056872037, 'byte_scores': 0.5000084869814966, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:51,158:INFO -- Response status code: 200
# 2024-10-22 12:39:51,159:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:51,261:INFO -- Sending payload: {'switch': 1, 'in_port': 2, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 327, 'byte_count': 492580, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 249, 'byte_count_shifted': 375566, 'packet_count_average': 373.5, 'byte_count_average': 507216.00000000006, 'byte_count_average_norm': 0.1021813643188859, 'packet_count_average_norm': 0.14019157852724, 'byte_scores': 0.5, 'packet_scores': 0.8333322752431156, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:51,359:INFO -- Response status code: 200
# 2024-10-22 12:39:51,360:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:51,465:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:06', 'packet_count': 13, 'byte_count': 12280, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 5, 'byte_count_shifted': 5716, 'packet_count_average': 10.8, 'byte_count_average': 4707.800000000001, 'byte_count_average_norm': 0.0294499114752748, 'packet_count_average_norm': 0.3076923076923077, 'byte_scores': 0.8333166873156599, 'packet_scores': 0.5000153507651093, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:51,564:INFO -- Response status code: 200
# 2024-10-22 12:39:51,565:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:51,669:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 5, 'byte_count': 210, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 11, 'packet_count_shifted': 4, 'byte_count_shifted': 168, 'packet_count_average': 6.800000000000001, 'byte_count_average': 6072.599999999999, 'byte_count_average_norm': 0.1099395667532024, 'packet_count_average_norm': 0.1458333333333333, 'byte_scores': 0.833319757693972, 'packet_scores': 0.500018082487848, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:51,766:INFO -- Response status code: 200
# 2024-10-22 12:39:51,766:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:51,870:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 5, 'byte_count': 210, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 4, 'byte_count_shifted': 168, 'packet_count_average': 5.5, 'byte_count_average': 5267.800000000003, 'byte_count_average_norm': 0.0695910861099092, 'packet_count_average_norm': 0.0797872340425531, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:51,972:INFO -- Response status code: 200
# 2024-10-22 12:39:51,972:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:52,077:INFO -- Sending payload: {'switch': 1, 'in_port': 3, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 927, 'byte_count': 1400702, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 517, 'byte_count_shifted': 781704, 'packet_count_average': 771.3, 'byte_count_average': 932776.6000000002, 'byte_count_average_norm': 0.0754874167308574, 'packet_count_average_norm': 0.1508172725054891, 'byte_scores': 0.5000027544259675, 'packet_scores': 0.8333329903637829, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:52,178:INFO -- Response status code: 200
# 2024-10-22 12:39:52,179:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:52,282:INFO -- Sending payload: {'switch': 2, 'in_port': 1, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.8333333333111111, 'packet_scores': 0.8333333333111111, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:52,381:INFO -- Response status code: 200
# 2024-10-22 12:39:52,382:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:52,486:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.8333333333111111, 'packet_scores': 0.8333333333111111, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:52,581:INFO -- Response status code: 200
# 2024-10-22 12:39:52,582:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:52,687:INFO -- Sending payload: {'switch': 2, 'in_port': 3, 'eth_dst': '00:00:00:00:00:05', 'packet_count': 6427, 'byte_count': 9712292, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 6313, 'byte_count_shifted': 9540846, 'packet_count_average': 5199.0, 'byte_count_average': 7856567.6, 'byte_count_average_norm': 0.3738092191385833, 'packet_count_average_norm': 0.3738452361901159, 'byte_scores': 0.5, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:52,784:INFO -- Response status code: 200
# 2024-10-22 12:39:52,784:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:52,888:INFO -- Sending payload: {'switch': 2, 'in_port': 1, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.8333333333111111, 'packet_scores': 0.8333333333111111, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:52,984:INFO -- Response status code: 200
# 2024-10-22 12:39:52,984:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:53,090:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 6.100000000000001, 'byte_count_average': 7466.6, 'byte_count_average_norm': 0.1819641423601819, 'packet_count_average_norm': 0.1, 'byte_scores': 0.8333279659063042, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:53,186:INFO -- Response status code: 200
# 2024-10-22 12:39:53,186:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:53,291:INFO -- Sending payload: {'switch': 2, 'in_port': 5, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 234, 'byte_count': 353808, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 136, 'byte_count_shifted': 205632, 'packet_count_average': 568.3, 'byte_count_average': 656332.5, 'byte_count_average_norm': 0.117392114017602, 'packet_count_average_norm': 0.2663852477227282, 'byte_scores': 0.5000014630375349, 'packet_scores': 0.8333323229740941, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:53,395:INFO -- Response status code: 200
# 2024-10-22 12:39:53,396:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:53,502:INFO -- Sending payload: {'switch': 1, 'in_port': 5, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 4185, 'byte_count': 6322388, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 1279, 'byte_count_shifted': 1930908, 'packet_count_average': 729.0, 'byte_count_average': 826052.5999999999, 'byte_count_average_norm': 0.1175734013686941, 'packet_count_average_norm': 0.2152874424579809, 'byte_scores': 0.5000253675990134, 'packet_scores': 0.8333287278304873, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:53,600:INFO -- Response status code: 200
# 2024-10-22 12:39:53,601:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:53,706:INFO -- Sending payload: {'switch': 2, 'in_port': 4, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 17184, 'byte_count': 25963246, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 1616, 'byte_count_shifted': 2443392, 'packet_count_average': 505.8, 'byte_count_average': 897501.9, 'byte_count_average_norm': 0.0664036651414, 'packet_count_average_norm': 0.0008955223880597, 'byte_scores': 0.5000022230523885, 'packet_scores': 0.833328768055718, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:53,802:INFO -- Response status code: 200
# 2024-10-22 12:39:53,802:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:53,907:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:03', 'packet_count': 3, 'byte_count': 1596, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 3, 'byte_count_shifted': 1596, 'packet_count_average': 118.6, 'byte_count_average': 121785.6, 'byte_count_average_norm': 0.9721011350281786, 'packet_count_average_norm': 0.925925925925926, 'byte_scores': 0.833332303895767, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:54,002:INFO -- Response status code: 200
# 2024-10-22 12:39:54,002:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:54,105:INFO -- Sending payload: {'switch': 2, 'in_port': 3, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 29161, 'byte_count': 44062876, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 1300, 'byte_count_shifted': 1965600, 'packet_count_average': 735.4, 'byte_count_average': 777875.4, 'byte_count_average_norm': 0.0356042432491743, 'packet_count_average_norm': 0.1624010099850797, 'byte_scores': 0.8333280506430141, 'packet_scores': 0.5000173750523956, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:54,203:INFO -- Response status code: 200
# 2024-10-22 12:39:54,203:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:54,307:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.8333333333111111, 'packet_scores': 0.8333333333111111, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:54,406:INFO -- Response status code: 200
# 2024-10-22 12:39:54,407:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:54,510:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.8333333333111111, 'packet_scores': 0.8333333333111111, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:54,606:INFO -- Response status code: 200
# 2024-10-22 12:39:54,607:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:54,712:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:01', 'packet_count': 11, 'byte_count': 10178, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 8, 'byte_count_shifted': 6564, 'packet_count_average': 8.2, 'byte_count_average': 5704.400000000001, 'byte_count_average_norm': 0.0827225672877847, 'packet_count_average_norm': 0.1990521327014217, 'byte_scores': 0.8333069786136102, 'packet_scores': 0.5, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:54,809:INFO -- Response status code: 200
# 2024-10-22 12:39:54,809:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:54,915:INFO -- Sending payload: {'switch': 1, 'in_port': 1, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 998, 'byte_count': 1504740, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 958, 'byte_count_shifted': 1444260, 'packet_count_average': 6932.1, 'byte_count_average': 10501154.8, 'byte_count_average_norm': 0.9742282188463806, 'packet_count_average_norm': 0.9715883998233475, 'byte_scores': 0.5, 'packet_scores': 0.8333325181527312, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:55,011:INFO -- Response status code: 200
# 2024-10-22 12:39:55,012:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:55,117:INFO -- Sending payload: {'switch': 2, 'in_port': 4, 'eth_dst': '00:00:00:00:00:05', 'packet_count': 9083, 'byte_count': 13729086, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 2386, 'byte_count_shifted': 3604692, 'packet_count_average': 8140.4, 'byte_count_average': 12304168.8, 'byte_count_average_norm': 0.3966829499900126, 'packet_count_average_norm': 0.3967163679008209, 'byte_scores': 0.7500816594014063, 'packet_scores': 0.7500816657069398, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:55,215:INFO -- Response status code: 200
# 2024-10-22 12:39:55,216:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:55,318:INFO -- Sending payload: {'switch': 1, 'in_port': 2, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 327, 'byte_count': 492580, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 249, 'byte_count_shifted': 375566, 'packet_count_average': 380.5, 'byte_count_average': 527174.4000000001, 'byte_count_average_norm': 0.1153531808131174, 'packet_count_average_norm': 0.1471762123328676, 'byte_scores': 0.5, 'packet_scores': 0.5000003559150527, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:55,415:INFO -- Response status code: 200
# 2024-10-22 12:39:55,416:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:55,520:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:06', 'packet_count': 13, 'byte_count': 12280, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 5, 'byte_count_shifted': 5716, 'packet_count_average': 10.4, 'byte_count_average': 4501.800000000001, 'byte_count_average_norm': 0.0188475316012682, 'packet_count_average_norm': 0.2895927601809954, 'byte_scores': 0.5000061336338124, 'packet_scores': 0.8333003560693779, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:55,614:INFO -- Response status code: 200
# 2024-10-22 12:39:55,614:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:55,718:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 5, 'byte_count': 210, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 4, 'byte_count_shifted': 168, 'packet_count_average': 6.900000000000002, 'byte_count_average': 6022.0, 'byte_count_average_norm': 0.1072477337532451, 'packet_count_average_norm': 0.1510416666666668, 'byte_scores': 0.833319757693972, 'packet_scores': 0.833306962350872, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:55,819:INFO -- Response status code: 200
# 2024-10-22 12:39:55,820:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:39:55,924:INFO -- Sending payload: {'switch': 2, 'in_port': 1, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 12, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': 0.8333333333111111, 'packet_scores': 0.8333333333111111, 'byte_anomaly': 1, 'packet_anomaly': 1}
# 2024-10-22 12:39:56,021:INFO -- Response status code: 200
# 2024-10-22 12:39:56,021:INFO -- Response content: b'{"status":"success"}'
# ...
# 2024-10-22 12:40:38,891:INFO -- Response status code: 200
# 2024-10-22 12:40:38,891:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:38,996:INFO -- Sending payload: {'switch': 1, 'in_port': 1, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 4058, 'byte_count': 6129990, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 18, 'packet_count_shifted': 3690, 'byte_count_shifted': 5576340, 'packet_count_average': 6940.8, 'byte_count_average': 10330403.8, 'byte_count_average_norm': 0.9557473961349754, 'packet_count_average_norm': 0.9730114333382404, 'byte_scores': -2.1666703094580173, 'packet_scores': -2.166660078830011, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:39,707:INFO -- Response status code: 200
# 2024-10-22 12:40:39,707:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:39,813:INFO -- Sending payload: {'switch': 1, 'in_port': 3, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 1190, 'byte_count': 1798358, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 18, 'packet_count_shifted': 502, 'byte_count_shifted': 759024, 'packet_count_average': 730.6000000000001, 'byte_count_average': 902070.4, 'byte_count_average_norm': 0.0655784734724672, 'packet_count_average_norm': 0.1309587704318126, 'byte_scores': -2.166654636203187, 'packet_scores': -2.1666552982362712, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:39,917:INFO -- Response status code: 200
# 2024-10-22 12:40:39,917:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:40,023:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:01', 'packet_count': 14, 'byte_count': 12870, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 18, 'packet_count_shifted': 4, 'byte_count_shifted': 4204, 'packet_count_average': 6.800000000000001, 'byte_count_average': 5745.599999999998, 'byte_count_average_norm': 0.084855072463768, 'packet_count_average_norm': 0.1327014218009479, 'byte_scores': -2.1662332939970903, 'packet_scores': -2.1667988031328904, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:40,123:INFO -- Response status code: 200
# 2024-10-22 12:40:40,124:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:40,227:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 19, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': -2.833333333111111, 'packet_scores': -2.833333333111111, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:40,362:INFO -- Response status code: 200
# 2024-10-22 12:40:40,362:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:40,464:INFO -- Sending payload: {'switch': 2, 'in_port': 5, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 368, 'byte_count': 556416, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 19, 'packet_count_shifted': 270, 'byte_count_shifted': 408240, 'packet_count_average': 461.8999999999999, 'byte_count_average': 709248.3, 'byte_count_average_norm': 0.1562646761629912, 'packet_count_average_norm': 0.1481892912686068, 'byte_scores': -2.832672475267662, 'packet_scores': -2.833557031421301, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:40,566:INFO -- Response status code: 200
# 2024-10-22 12:40:40,566:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:40,669:INFO -- Sending payload: {'switch': 2, 'in_port': 1, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 2, 'byte_count': 84, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 19, 'packet_count_shifted': 2, 'byte_count_shifted': 84, 'packet_count_average': 0.2, 'byte_count_average': 8.4, 'byte_count_average_norm': 4.5921915250012026e-05, 'packet_count_average_norm': 0.0010869565217391, 'byte_scores': -2.8333333332198998, 'packet_scores': -2.8333333940601904, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:40,781:INFO -- Response status code: 200
# 2024-10-22 12:40:40,781:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:40,885:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:07', 'packet_count': 7, 'byte_count': 294, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 19, 'packet_count_shifted': 3, 'byte_count_shifted': 126, 'packet_count_average': 7.5, 'byte_count_average': 6560.399999999998, 'byte_count_average_norm': 0.1358896880452822, 'packet_count_average_norm': 0.1822916666666666, 'byte_scores': -2.833266528704046, 'packet_scores': -2.833280486788708, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:41,062:INFO -- Response status code: 200
# 2024-10-22 12:40:41,062:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:41,165:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:03', 'packet_count': 10, 'byte_count': 9414, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 19, 'packet_count_shifted': 8, 'byte_count_shifted': 9330, 'packet_count_average': 120.1, 'byte_count_average': 122782.4, 'byte_count_average_norm': 0.9814577020842016, 'packet_count_average_norm': 0.9398148148148148, 'byte_scores': -2.833321219785081, 'packet_scores': -2.8333357826477954, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:41,269:INFO -- Response status code: 200
# 2024-10-22 12:40:41,269:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:41,375:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:06', 'packet_count': 17, 'byte_count': 16484, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 19, 'packet_count_shifted': 7, 'byte_count_shifted': 7818, 'packet_count_average': 7.5, 'byte_count_average': 6271.800000000001, 'byte_count_average_norm': 0.1099456499361798, 'packet_count_average_norm': 0.1583710407239819, 'byte_scores': -2.8336125111312738, 'packet_scores': -2.8331689541085865, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:41,477:INFO -- Response status code: 200
# 2024-10-22 12:40:41,477:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:41,579:INFO -- Sending payload: {'switch': 2, 'in_port': 2, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 0, 'byte_count': 0, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 19, 'packet_count_shifted': 0, 'byte_count_shifted': 0, 'packet_count_average': 0.0, 'byte_count_average': 0.0, 'byte_count_average_norm': 0.0, 'packet_count_average_norm': 0.0, 'byte_scores': -2.833333333111111, 'packet_scores': -2.833333333111111, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:41,712:INFO -- Response status code: 200
# 2024-10-22 12:40:41,712:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:41,815:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:02', 'packet_count': 1, 'byte_count': 42, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 19, 'packet_count_shifted': 1, 'byte_count_shifted': 42, 'packet_count_average': 6.100000000000001, 'byte_count_average': 8067.199999999999, 'byte_count_average_norm': 0.2128712871287127, 'packet_count_average_norm': 0.1, 'byte_scores': -2.832862490504437, 'packet_scores': -2.8331947660395222, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:41,917:INFO -- Response status code: 200
# 2024-10-22 12:40:41,917:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:42,022:INFO -- Sending payload: {'switch': 1, 'in_port': 4, 'eth_dst': '00:00:00:00:00:08', 'packet_count': 7, 'byte_count': 294, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 19, 'packet_count_shifted': 3, 'byte_count_shifted': 126, 'packet_count_average': 5.299999999999997, 'byte_count_average': 6838.800000000003, 'byte_count_average_norm': 0.1545651233232368, 'packet_count_average_norm': 0.0691489361702126, 'byte_scores': -2.833596109832235, 'packet_scores': -2.8332448644752173, 'byte_anomaly': -1, 'packet_anomaly': -1}
# 2024-10-22 12:40:42,126:INFO -- Response status code: 200
# 2024-10-22 12:40:42,126:INFO -- Response content: b'{"status":"success"}'
# 2024-10-22 12:40:42,227:INFO -- Sending payload: {'switch': 2, 'in_port': 4, 'eth_dst': '00:00:00:00:00:04', 'packet_count': 18272, 'byte_count': 27608302, 'user_id': 'aaltosea1', 'instance_id': 'rohe_test_isntance', 'run_id': 'experiment1', 'stage_id': 'rohe_test_stage', 'application_name': 'sdn', 'runtime': 19, 'packet_count_shifted': 1570, 'byte_count_shifted': 2373840, 'packet_count_average': 575.8999999999999, 'byte_count_average': 887069.0999999997, 'byte_count_average_norm': 0.0612543908239385, 'packet_count_average_norm': 0.0532089552238805, 'byte_scores': -2.8333114362571026, 'packet_scores': -2.8334260435812078, 'byte_anomaly': -1, 'packet_anomaly': -1}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[100], line 19
#      17 pay_load = row.to_dict()
#      18 logging.info(f"Sending payload: {pay_load}")
# ---> 19 response = requests.post(url, json=pay_load)
#      20 logging.info(f"Response status code: {response.status_code}")
#      21 logging.info(f"Response content: {response.content}")
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/rxoms/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # Test With specific data records

# %%
# Test Data Enrichment APIs
import pandas as pd
import time

data_path = str(RXOMS_PATH) + DEFAULT_DATA_PATH + "all_flow.csv"

url = "http://0.0.0.0:5051/anomaly_report"

pay_loads = [
    {
        "switch": 1,
        "in_port": 5,
        "eth_dst": "00:00:00:00:00:04",
        "packet_count": 368,
        "byte_count": 5739366,
        "user_id": "aaltosea1",
        "instance_id": "rohe_test_isntance",
        "run_id": "experiment1",
        "stage_id": "rohe_test_stage",
        "application_name": "sdn",
        "runtime": 10,
        "packet_count_shifted": 328,
        "byte_count_shifted": 493170,
        "packet_count_average": 6958.2,
        "byte_count_average": 10548648.4,
        "byte_count_average_norm": 0.9793685741094618,
        "packet_count_average_norm": 0.975857500368026,
        "byte_scores": 0.7,
        "packet_scores": 0.799999445188199,
        "byte_anomaly": -1,
        "packet_anomaly": -1,
    },
    {
        "switch": 2,
        "in_port": 5,
        "eth_dst": "00:00:00:00:00:04",
        "packet_count": 368,
        "byte_count": 6846438,
        "user_id": "aaltosea1",
        "instance_id": "rohe_test_isntance",
        "run_id": "experiment1",
        "stage_id": "rohe_test_stage",
        "application_name": "sdn",
        "runtime": 10,
        "packet_count_shifted": 328,
        "byte_count_shifted": 493170,
        "packet_count_average": 6958.2,
        "byte_count_average": 10548648.4,
        "byte_count_average_norm": 0.9793685741094618,
        "packet_count_average_norm": 0.975857500368026,
        "byte_scores": 0.7,
        "packet_scores": 0.799999445188199,
        "byte_anomaly": -1,
        "packet_anomaly": -1,
    },
    {
        "switch": 2,
        "in_port": 2,
        "eth_dst": "00:00:00:00:00:02",
        "packet_count": 368,
        "byte_count": 2,
        "user_id": "aaltosea1",
        "instance_id": "rohe_test_isntance",
        "run_id": "experiment1",
        "stage_id": "rohe_test_stage",
        "application_name": "sdn",
        "runtime": 10,
        "packet_count_shifted": 328,
        "byte_count_shifted": 493170,
        "packet_count_average": 6958.2,
        "byte_count_average": 10548648.4,
        "byte_count_average_norm": 0.9793685741094618,
        "packet_count_average_norm": 0.975857500368026,
        "byte_scores": 0.7,
        "packet_scores": 0.799999445188199,
        "byte_anomaly": -1,
        "packet_anomaly": -1,
    },
    {
        "switch": 2,
        "in_port": 1,
        "eth_dst": "00:00:00:00:00:02",
        "packet_count": 368,
        "byte_count": 2,
        "user_id": "aaltosea1",
        "instance_id": "rohe_test_isntance",
        "run_id": "experiment1",
        "stage_id": "rohe_test_stage",
        "application_name": "sdn",
        "runtime": 10,
        "packet_count_shifted": 328,
        "byte_count_shifted": 493170,
        "packet_count_average": 6958.2,
        "byte_count_average": 10548648.4,
        "byte_count_average_norm": 0.9793685741094618,
        "packet_count_average_norm": 0.975857500368026,
        "byte_scores": 0.7,
        "packet_scores": 0.799999445188199,
        "byte_anomaly": -1,
        "packet_anomaly": -1,
    },
    {
        "switch": 1,
        "in_port": 4,
        "eth_dst": "00:00:00:00:00:02",
        "packet_count": 368,
        "byte_count": 2,
        "user_id": "aaltosea1",
        "instance_id": "rohe_test_isntance",
        "run_id": "experiment1",
        "stage_id": "rohe_test_stage",
        "application_name": "sdn",
        "runtime": 10,
        "packet_count_shifted": 328,
        "byte_count_shifted": 493170,
        "packet_count_average": 6958.2,
        "byte_count_average": 10548648.4,
        "byte_count_average_norm": 0.9793685741094618,
        "packet_count_average_norm": 0.975857500368026,
        "byte_scores": 0.7,
        "packet_scores": 0.799999445188199,
        "byte_anomaly": -1,
        "packet_anomaly": -1,
    },
]
for pay_load in pay_loads:
    logging.info(f"Sending payload: {pay_load}")
    response = requests.post(url, json=pay_load)
    logging.info(f"Response status code: {response.status_code}")
    logging.info(f"Response content: {response.content}")
